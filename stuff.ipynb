# %%
import sys
import pandas as pd

sys.path.append('../../Advanced Physics Laboratory/T-junction/Software/Python/Library')

import uplotlib as uplt

# %%
df = pd.read_csv('HW1/regression/random_search5.csv',usecols=['Nh1', 'Nh2', 'Nh3', 'Nh4', 'activation_function',
       'dropout_prob_2', 'dropout_prob_3', 'lr',
       'weight_decay', 'train_batch_size', 'patience', 'avg_train_loss',
       'avg_val_loss', 'train_time'])

# %%
uplt.df2latex(df,float_digits=4)
# Out:
# $8$ & $64$ & $64$ & $16$ & ReLU() & $0.0000$ & $0.1500$ & $0.0010$ & $0.0005$ & $30$ & $300$ & $0.3359$ & $0.3492$ & $0.5375$ \\
# $128$ & $256$ & $32$ & $64$ & ReLU() & $0.1500$ & $0.1500$ & $0.0005$ & $0.0001$ & $30$ & $400$ & $0.3903$ & $0.4936$ & $0.5259$ \\
# $32$ & $128$ & $256$ & $64$ & ReLU() & $0.1500$ & $0.0000$ & $0.0500$ & $0.0005$ & $40$ & $200$ & $0.5958$ & $0.6237$ & $0.2418$ \\
# $128$ & $16$ & $16$ & $256$ & Tanh() & $0.3500$ & $0.0000$ & $0.0005$ & $0.0001$ & $40$ & $300$ & $0.6072$ & $0.5363$ & $0.4125$ \\
# $64$ & $256$ & $256$ & $128$ & Tanh() & $0.0000$ & $0.5000$ & $0.0010$ & $0.0005$ & $40$ & $300$ & $0.2840$ & $0.3632$ & $0.3951$ \\
# $32$ & $64$ & $128$ & $64$ & Tanh() & $0.1500$ & $0.5000$ & $0.0100$ & $0.0001$ & $50$ & $400$ & $0.4304$ & $0.4927$ & $0.4649$ \\
# $16$ & $128$ & $256$ & $256$ & ReLU() & $0.3500$ & $0.3500$ & $0.0010$ & $0.0005$ & $30$ & $100$ & $0.8441$ & $0.7010$ & $0.1999$ \\
# ...

# %%
for k in df.columns:
    print(f'{k} & ',end='')
# Out:
# Nh1 & Nh2 & Nh3 & Nh4 & activation_function & dropout_prob_2 & dropout_prob_3 & lr & weight_decay & train_batch_size & patience & avg_train_loss & avg_val_loss & train_time &
